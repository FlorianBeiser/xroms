# %%
import xarray as xr
import xroms
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/florianb/xroms/xroms/interp.py:18: UserWarning: xESMF is not installed, so `interpll` will not run.
#   warnings.warn("xESMF is not installed, so `interpll` will not run.")

# %% [markdown]
# # How to select data
#
# The [input/output](io.ipynb) notebook demonstrates how to load in data, but now how to select and slice it apart? Much of this is accomplished with the `sel` and `isel` methods in `xarray`, which are demonstrated in detail in this notebook.
# * Use `sel` to subdivide a Dataset or DataArray by dimension values; the best example of this for ROMS output is selecting certain time using a string representation of a datetime.
#
#     >ds.salt.sel(ocean_time='2010-1-1 12:00')
#
#     >ds.salt.sel(ocean_time=slice('2010-1-1', '2010-2-1'))
#
# * Use `isel` to subdivide a Dataset or DataArray by dimension indices:
#
#     >ds.salt.isel(eta_rho=20, xi_rho=100)
#
#     >ds.salt.isel(eta_rho=slice(20,100,10), xi_rho=slice(None,None,5))

# %% [markdown]
# ## `cf-xarray`
#
# `xroms` includes the `cf-xarray` accessor, which allows you to use xarray `sel` and `isel` commands for a DataArray without needing to input the exact grid – just the axes.
#
# With `xarray` alone:
#
#     >ds.salt.isel(xi_rho=20, eta_rho=10, s_rho=20, ocean_time=10)
#
# With `cf-xarray` accessor:
#
#     >ds.salt.cf.isel(X=20, Y=10, Z=20, T=10)
#
# and get the same thing back. Same for `sel`. The T, Z, Y, X names can be mixed and matched with the actual dimension names. Some of the attribute wrangling in `xroms` is dedicated to making sure that `cf-xarray` can always identify dimensions and coordinates for DataArrays.
#
# You can always check what `cf-xarray` understands about a Dataset or DataArray with
#
#     ds.salt.cf.describe()

# %% [markdown]
# ### Load in data
#
# More information at in [input/output notebook](io.ipynb)

# %%
# Helpful to have local file for this
url = 'http://barataria.tamu.edu:8080/thredds/fileServer/forecast_latest/txla2_his_a_latest.nc'
fname = url.split('/')[-1]
chunks = {'ocean_time': 1}

import os
if os.path.exists(fname):
    ds = xroms.open_netcdf(fname, chunks=chunks)
else:
    from subprocess import call
    call(['wget', url])
    ds = xroms.open_netcdf(fname, chunks=chunks)
    
# Alternatively, use file through thredds:
# loc = 'http://barataria.tamu.edu:8080/thredds/dodsC/forecast_latest/txla2_his_f_latest.nc'
# chunks = {'ocean_time':1}
# ds = xr.open_dataset(loc, chunks=chunks)

# %% [markdown]
# ## Select

# %% [markdown]
# ### Surface layer slice
#
# The surface in ROMS is given by the last index in the vertical dimension. The easiest way to access this is by indexing into `s_rho`. While normally it is better to access coordinates through keywords to be human-readable, it's not easy to tell what value of `s_rho` gives the surface. In this instance, it's easier to just go by index.

# %%
ds.salt.isel(s_rho=-1);

# or with cf-xarray accessor:
ds.salt.cf.isel(Z=-1);

# %% [markdown]
# ### x/y index slice
#
# For a curvilinear ROMS grid, selecting by the dimensions `xi_rho` or `eta_rho` (or for whichever is the relevant grid) is not very meaningful because they are given by index. Thus the following is possible to get a slice along the index, but it cannot be used to find a slice based on the lon/lat values. For the eta and xi grids, `sel` is equivalent to `isel`.

# %%
ds.temp.sel(xi_rho=20);

ds.temp.cf.sel(X=20);  # same with cf-xarray accessor

# %% [markdown]
# ### Single time
#
# Find the forecast model output available that is closest to now. Note that the `method` keyword argument is not necessary if the desired date/time is exactly a model output time. You can daisy-chain together different `sel` and `isel` calls.

# %%
now = pd.Timestamp.today()

# %%
ds.salt.isel(s_rho=-1).sel(ocean_time=now, method='nearest');

ds.salt.cf.isel(Z=-1).cf.sel(T=now, method='nearest');

# %% [markdown]
# ### Range of time

# %%
ds.salt.sel(ocean_time=slice(now, now+pd.Timedelta('2 days')));

ds.salt.cf.sel(T=slice(now, now+pd.Timedelta('2 days')));

# %% [markdown]
# ### Select region
#
# Select a boxed region by min/max lon and lat values.

# %%
# want model output only within the box defined by these lat/lon values
lon = np.array([-97, -96])
lat = np.array([28, 29])

# %%
# this condition defines the region of interest
box = ((lon[0] < ds.lon_rho) & (ds.lon_rho < lon[1]) & (lat[0] < ds.lat_rho) & (ds.lat_rho < lat[1])).compute()

# %% [markdown]
# Plot the model output in the box at the surface

# %%
dss = ds.where(box).salt.cf.isel(Z=-1, T=0)
dss.cf.plot(x='longitude', y='latitude')

# %% [markdown]
# If you don't need the rest of the model output, you can drop it by using `drop=True` in the `where` call.

# %%
dss = ds.where(box, drop=True).salt.cf.isel(Z=-1, T=0)
dss.cf.plot(x='longitude', y='latitude')
# Out:
# /home/florianb/miniconda3/envs/XROMS/lib/python3.8/site-packages/xarray/core/indexing.py:1228: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]

# %% [markdown]
# Can calculate a metric within the box:

# %%
dss.mean().values
# Out:
# array(29.132664, dtype=float32)

# %% [markdown]
# ### Subset model output
#
# Subset Dataset of model output such that subsetted domain is as if the simulation was run on that size grid. That is, the rho grid is 1 larger than the psi grid in each of xi and eta.

# %%
xroms.subset(ds, X=slice(20,40), Y=slice(50,100))
# Out:
# <xarray.Dataset>
# Dimensions:         (tracer: 6, s_rho: 30, s_w: 31, eta_rho: 50, xi_rho: 20,
#                      xi_u: 19, eta_v: 49, ocean_time: 96)
# Coordinates: (12/31)
#   * s_rho           (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w             (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.06667 -0.03333 0.0
#     lon_rho         (eta_rho, xi_rho) float64 dask.array<chunksize=(50, 20), meta=np.ndarray>
#     lat_rho         (eta_rho, xi_rho) float64 dask.array<chunksize=(50, 20), meta=np.ndarray>
#     lon_u           (eta_rho, xi_u) float64 dask.array<chunksize=(50, 19), meta=np.ndarray>
#     lat_u           (eta_rho, xi_u) float64 dask.array<chunksize=(50, 19), meta=np.ndarray>
#     ...              ...
#     z_rho_v0        (s_rho, eta_v, xi_rho) float64 dask.array<chunksize=(30, 49, 20), meta=np.ndarray>
#     z_rho_psi0      (s_rho, eta_v, xi_u) float64 dask.array<chunksize=(30, 49, 19), meta=np.ndarray>
#     z_w0            (s_w, eta_rho, xi_rho) float64 dask.array<chunksize=(31, 50, 20), meta=np.ndarray>
#     z_w_u0          (s_w, eta_rho, xi_u) float64 dask.array<chunksize=(31, 50, 19), meta=np.ndarray>
#     z_w_v0          (s_w, eta_v, xi_rho) float64 dask.array<chunksize=(31, 49, 20), meta=np.ndarray>
#     z_w_psi0        (s_w, eta_v, xi_u) float64 dask.array<chunksize=(31, 49, 19), meta=np.ndarray>
# Dimensions without coordinates: tracer
# Data variables: (12/144)
#     ntimes          int32 ...
#     ndtfast         int32 ...
#     dt              float64 ...
#     dtfast          float64 ...
#     dstart          datetime64[ns] ...
#     shuffle         int32 ...
#     ...              ...
#     dV_u            (ocean_time, s_rho, eta_rho, xi_u) float64 dask.array<chunksize=(1, 30, 50, 19), meta=np.ndarray>
#     dV_w_u          (ocean_time, s_w, eta_rho, xi_u) float64 dask.array<chunksize=(1, 1, 50, 19), meta=np.ndarray>
#     dV_v            (ocean_time, s_rho, eta_v, xi_rho) float64 dask.array<chunksize=(1, 30, 49, 20), meta=np.ndarray>
#     dV_w_v          (ocean_time, s_w, eta_v, xi_rho) float64 dask.array<chunksize=(1, 1, 49, 20), meta=np.ndarray>
#     dV_psi          (ocean_time, s_rho, eta_v, xi_u) float64 dask.array<chunksize=(1, 30, 49, 19), meta=np.ndarray>
#     dV_w_psi        (ocean_time, s_w, eta_v, xi_u) float64 dask.array<chunksize=(1, 1, 49, 19), meta=np.ndarray>
# Attributes: (12/33)
#     file:              /scratch/user/d.kobashi/projects/ROFS/projects/txla2/o...
#     format:            netCDF-4/HDF5 file
#     Conventions:       CF-1.4, SGRID-0.3
#     type:              ROMS/TOMS history file
#     title:             TXLA Regional Ocean Forecast Sysetm (ROFS) with dyes a...
#     var_info:          varinfo.dat
#     ...                ...
#     compiler_command:  /sw/eb/sw/impi/2019.9.304-iccifort-2020.4.304/intel64/...
#     compiler_flags:    -fp-model fast -heap-arrays -ip -O3
#     tiling:            010x012
#     history:           ROMS/TOMS, Version 3.7, Wednesday - May 11, 2022 -  3:...
#     ana_file:          /scratch/user/d.kobashi/source_code/COAWST/Functionals...
#     CPP_options:       TXLA2, ANA_BPFLUX, ANA_BSFLUX, ANA_BTFLUX, ANA_SPFLUX,...

# %%
ds.xroms.subset(X=slice(20,40), Y=slice(50,100))  # with accessor
# Out:
# <xarray.Dataset>
# Dimensions:         (tracer: 6, s_rho: 30, s_w: 31, eta_rho: 50, xi_rho: 20,
#                      xi_u: 19, eta_v: 49, ocean_time: 96)
# Coordinates: (12/31)
#   * s_rho           (s_rho) float64 -0.9833 -0.95 -0.9167 ... -0.05 -0.01667
#   * s_w             (s_w) float64 -1.0 -0.9667 -0.9333 ... -0.06667 -0.03333 0.0
#     lon_rho         (eta_rho, xi_rho) float64 dask.array<chunksize=(50, 20), meta=np.ndarray>
#     lat_rho         (eta_rho, xi_rho) float64 dask.array<chunksize=(50, 20), meta=np.ndarray>
#     lon_u           (eta_rho, xi_u) float64 dask.array<chunksize=(50, 19), meta=np.ndarray>
#     lat_u           (eta_rho, xi_u) float64 dask.array<chunksize=(50, 19), meta=np.ndarray>
#     ...              ...
#     z_rho_v0        (s_rho, eta_v, xi_rho) float64 dask.array<chunksize=(30, 49, 20), meta=np.ndarray>
#     z_rho_psi0      (s_rho, eta_v, xi_u) float64 dask.array<chunksize=(30, 49, 19), meta=np.ndarray>
#     z_w0            (s_w, eta_rho, xi_rho) float64 dask.array<chunksize=(31, 50, 20), meta=np.ndarray>
#     z_w_u0          (s_w, eta_rho, xi_u) float64 dask.array<chunksize=(31, 50, 19), meta=np.ndarray>
#     z_w_v0          (s_w, eta_v, xi_rho) float64 dask.array<chunksize=(31, 49, 20), meta=np.ndarray>
#     z_w_psi0        (s_w, eta_v, xi_u) float64 dask.array<chunksize=(31, 49, 19), meta=np.ndarray>
# Dimensions without coordinates: tracer
# Data variables: (12/144)
#     ntimes          int32 ...
#     ndtfast         int32 ...
#     dt              float64 ...
#     dtfast          float64 ...
#     dstart          datetime64[ns] ...
#     shuffle         int32 ...
#     ...              ...
#     dV_u            (ocean_time, s_rho, eta_rho, xi_u) float64 dask.array<chunksize=(1, 30, 50, 19), meta=np.ndarray>
#     dV_w_u          (ocean_time, s_w, eta_rho, xi_u) float64 dask.array<chunksize=(1, 1, 50, 19), meta=np.ndarray>
#     dV_v            (ocean_time, s_rho, eta_v, xi_rho) float64 dask.array<chunksize=(1, 30, 49, 20), meta=np.ndarray>
#     dV_w_v          (ocean_time, s_w, eta_v, xi_rho) float64 dask.array<chunksize=(1, 1, 49, 20), meta=np.ndarray>
#     dV_psi          (ocean_time, s_rho, eta_v, xi_u) float64 dask.array<chunksize=(1, 30, 49, 19), meta=np.ndarray>
#     dV_w_psi        (ocean_time, s_w, eta_v, xi_u) float64 dask.array<chunksize=(1, 1, 49, 19), meta=np.ndarray>
# Attributes: (12/33)
#     file:              /scratch/user/d.kobashi/projects/ROFS/projects/txla2/o...
#     format:            netCDF-4/HDF5 file
#     Conventions:       CF-1.4, SGRID-0.3
#     type:              ROMS/TOMS history file
#     title:             TXLA Regional Ocean Forecast Sysetm (ROFS) with dyes a...
#     var_info:          varinfo.dat
#     ...                ...
#     compiler_command:  /sw/eb/sw/impi/2019.9.304-iccifort-2020.4.304/intel64/...
#     compiler_flags:    -fp-model fast -heap-arrays -ip -O3
#     tiling:            010x012
#     history:           ROMS/TOMS, Version 3.7, Wednesday - May 11, 2022 -  3:...
#     ana_file:          /scratch/user/d.kobashi/source_code/COAWST/Functionals...
#     CPP_options:       TXLA2, ANA_BPFLUX, ANA_BSFLUX, ANA_BTFLUX, ANA_SPFLUX,...

# %% [markdown]
# ### Find nearest in lon/lat
#
# This matters for a curvilinear grid.
#
# Can't use `sel` because it will only search in one dimension for the nearest value and the dimensions are indices which are not necessarily geographic distance. Instead need to use a search for distance and use that for the `where` condition from the previous example. This functionality has been wrapped into `xroms.sel2d` (and its partner function `xroms.argsel2d`).

# %%
lon0, lat0 = -96, 27
saltsel = ds.salt.xroms.sel2d(lon0, lat0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/florianb/xroms/examples/select_data.ipynb Cell 29' in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bhavvarsel/home/florianb/xroms/examples/select_data.ipynb#ch0000028vscode-remote?line=0'>1</a> lon0, lat0 = -96, 27
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bhavvarsel/home/florianb/xroms/examples/select_data.ipynb#ch0000028vscode-remote?line=1'>2</a> saltsel = ds.salt.xroms.sel2d(lon0, lat0)
#
# File ~/xroms/xroms/accessor.py:1260, in xromsDataArrayAccessor.sel2d(self, lon0, lat0)
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1232'>1233</a> def sel2d(self, lon0, lat0):
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1233'>1234</a>     """Find the value of the var at closest location to lon0,lat0.
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1234'>1235</a>
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1235'>1236</a>     Inputs
#    (...)
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1256'>1257</a>     >>> ds.temp.xroms.sel2d(-96, 27)
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1257'>1258</a>     """
# -> <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1259'>1260</a>     return xroms.sel2d(
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1260'>1261</a>         self.da, self.da.cf["longitude"], self.da.cf["latitude"], lon0, lat0
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1261'>1262</a>     )
#
# File ~/xroms/xroms/utilities.py:651, in sel2d(var, lons, lats, lon0, lat0)
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=610'>611</a> """Find the value of the var at closest location to lon0,lat0.
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=611'>612</a>
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=612'>613</a> Inputs
#    (...)
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=646'>647</a> >>> xroms.sel2d(ds.temp, ds.lon_rho, ds.lat_rho, -96, 27)
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=647'>648</a> """
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=649'>650</a> assert isinstance(var, xr.DataArray), "Input a DataArray"
# --> <a href='file:///home/florianb/xroms/xroms/utilities.py?line=650'>651</a> inds = argsel2d(lons, lats, lon0, lat0)
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=651'>652</a> return var.cf.isel(Y=inds[0], X=inds[1])
#
# File ~/xroms/xroms/utilities.py:601, in argsel2d(lons, lats, lon0, lat0)
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=597'>598</a> pts = list(zip(*(np.asarray(lons).flatten(), np.asarray(lats).flatten())))
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=598'>599</a> endpts = list(zip(*(np.asarray(lon0).flatten(), np.asarray(lat0).flatten())))
# --> <a href='file:///home/florianb/xroms/xroms/utilities.py?line=600'>601</a> G = cartopy.geodesic.Geodesic()  # set up class
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=601'>602</a> dist = np.asarray(G.inverse(pts, endpts)[:, 0])  # select distances specifically
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=602'>603</a> iclosest = abs(np.asarray(dist)).argmin()  # find indices of closest point
#
# NameError: name 'cartopy' is not defined

# %% [markdown]
# Or, if you instead want the indices of the nearest grid node returned, you can call `argsel2d`:

# %%
ds.salt.xroms.argsel2d(lon0, lat0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/florianb/xroms/examples/select_data.ipynb Cell 31' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bhavvarsel/home/florianb/xroms/examples/select_data.ipynb#ch0000030vscode-remote?line=0'>1</a> ds.salt.xroms.argsel2d(lon0, lat0)
#
# File ~/xroms/xroms/accessor.py:1229, in xromsDataArrayAccessor.argsel2d(self, lon0, lat0)
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1203'>1204</a> def argsel2d(self, lon0, lat0):
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1204'>1205</a>     """Find the indices of coordinate pair closest to another point.
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1205'>1206</a>
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1206'>1207</a>     Inputs
#    (...)
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1225'>1226</a>     >>> ds.temp.xroms.argsel2d(-96, 27)
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1226'>1227</a>     """
# -> <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1228'>1229</a>     return xroms.argsel2d(
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1229'>1230</a>         self.da.cf["longitude"], self.da.cf["latitude"], lon0, lat0
#    <a href='file:///home/florianb/xroms/xroms/accessor.py?line=1230'>1231</a>     )
#
# File ~/xroms/xroms/utilities.py:601, in argsel2d(lons, lats, lon0, lat0)
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=597'>598</a> pts = list(zip(*(np.asarray(lons).flatten(), np.asarray(lats).flatten())))
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=598'>599</a> endpts = list(zip(*(np.asarray(lon0).flatten(), np.asarray(lat0).flatten())))
# --> <a href='file:///home/florianb/xroms/xroms/utilities.py?line=600'>601</a> G = cartopy.geodesic.Geodesic()  # set up class
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=601'>602</a> dist = np.asarray(G.inverse(pts, endpts)[:, 0])  # select distances specifically
#     <a href='file:///home/florianb/xroms/xroms/utilities.py?line=602'>603</a> iclosest = abs(np.asarray(dist)).argmin()  # find indices of closest point
#
# NameError: name 'cartopy' is not defined

# %% [markdown]
# Check this function, just to be sure:

# %%
dl = 0.05
box = (ds.lon_rho>lon0-dl) & (ds.lon_rho<lon0+dl) & (ds.lat_rho>lat0-dl) & (ds.lat_rho<lat0+dl)
dss = ds.where(box).salt.cf.isel(T=0, Z=-1)

vmin = dss.min().values
vmax = dss.max().values

dss.plot(x='lon_rho', y='lat_rho')
plt.scatter(lon0, lat0, c=saltsel.cf.isel(Z=-1, T=0), s=200, edgecolor='k', vmin=vmin, vmax=vmax)
plt.xlim(lon0-dl,lon0+dl)
plt.ylim(lat0-dl, lat0+dl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/florianb/xroms/examples/select_data.ipynb Cell 33' in <cell line: 9>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bhavvarsel/home/florianb/xroms/examples/select_data.ipynb#ch0000032vscode-remote?line=5'>6</a> vmax = dss.max().values
#       <a href='vscode-notebook-cell://ssh-remote%2Bhavvarsel/home/florianb/xroms/examples/select_data.ipynb#ch0000032vscode-remote?line=7'>8</a> dss.plot(x='lon_rho', y='lat_rho')
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bhavvarsel/home/florianb/xroms/examples/select_data.ipynb#ch0000032vscode-remote?line=8'>9</a> plt.scatter(lon0, lat0, c=saltsel.cf.isel(Z=-1, T=0), s=200, edgecolor='k', vmin=vmin, vmax=vmax)
#      <a href='vscode-notebook-cell://ssh-remote%2Bhavvarsel/home/florianb/xroms/examples/select_data.ipynb#ch0000032vscode-remote?line=9'>10</a> plt.xlim(lon0-dl,lon0+dl)
#      <a href='vscode-notebook-cell://ssh-remote%2Bhavvarsel/home/florianb/xroms/examples/select_data.ipynb#ch0000032vscode-remote?line=10'>11</a> plt.ylim(lat0-dl, lat0+dl)
#
# NameError: name 'saltsel' is not defined
